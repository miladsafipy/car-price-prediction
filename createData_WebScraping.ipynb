# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## 2. Function to Scraping Data
#
# #### Scraping data to get name, year, price etc of cars
# #### WebAddress: https://www.cazoo.co.uk/cars/

# %%
def cazoo_web_scraping(pages):

    all_data = []
    
    # Pagination
    for p in range(1, pages+1):
        if p == 1:
            full_url = 'https://www.cazoo.co.uk/cars/'
        else:
            full_url = f'https://www.cazoo.co.uk/cars/?page={p}'

        # Request to web
        response = requests.get(full_url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find list of cars
        my_list = soup.find('ul', attrs={'class': 'grid min-h-96 grid-cols-1 content-start gap-4'})
        cars = my_list.find_all('li')

        for features in cars:
            try:
                # Get Price and clean it to save as digit
                price_tag = features.find('span', attrs={'class':'c-text-lg-semi-bold md:c-heading-xl'})
                price = price_tag.get_text() if price_tag else None
                price_clean = price.replace('£', '').replace(',', '')
                price_clean = int(price_clean) if price_clean.isdigit() else None

                # get brands- for brands with 2 or more section --> multi_word_brands
                multi_word_brands = ["Land Rover", "Alfa Romeo", "Mercedes Benz", "Aston Martin", "Rolls Royce", "Mini Cooper"]
                bm_tag = features.find('p', attrs={'data-testid': 'vehicleTitle'})
                bm = bm_tag.get_text() if bm_tag else None

                brand = None
                model = None
                if bm:
                    found = False
                    for b in multi_word_brands:
                        if bm.startswith(b):
                            brand = b
                            model = bm[len(b):].strip()
                            found = True
                            break
                    
                    if not found:
                        section = bm.split(' ', 1)
                        brand = section[0]
                        model = section[1] if len(section) > 1 else None

                # year and clean it to save as digit
                attrebutes_tag = features.find('p', attrs={'class': 'c-text-sm line-clamp-1 leading-tight'})
                attrebutes = attrebutes_tag.get_text() if attrebutes_tag else None
                parts = attrebutes.split(' ', 1)
                year = parts[0] if len(parts) > 0 else ''
                other_attr = parts[1] if len(parts) > 1 else ''
                year_clean = int(year) if year.isdigit() else None

                # Mile, Power, Manual/Auto, Energy
                properties = features.find('div', attrs={'class': 'flex flex-wrap items-center gap-2 pt-1 pb-3 lg:pt-0'})
                miles_tag = properties.find_all('div')[0]
                miles = miles_tag.get_text() if miles_tag else None
                miles_clean = int(miles.lower().replace('k', '').split()[0])
                register_tag = properties.find_all('div')[1]
                register = register_tag.get_text() if register_tag else None
                manAuto_tag = properties.find_all('div')[2]
                manAuto = manAuto_tag.get_text() if manAuto_tag else None
                fuel_tag = properties.find_all('div')[3]
                fuel = fuel_tag.get_text() if fuel_tag else None

                # Location
                location_tag = features.find('div', attrs={'class': 'c-text-xs flex items-center space-x-1'}).find('span')
                location = location_tag.get_text() if location_tag else None

                # Add all features to list
                all_data.append({
                    'Brand': brand,
                    'Model': model,
                    'Year': year_clean,
                    'Attrebutes': other_attr,
                    'Miles(k miles)': miles_clean,
                    'Registration': register,
                    'Control': manAuto,
                    'Fuel': fuel,
                    'Location': location,
                    'Price(£)': price_clean
                })

            except Exception as e:
                print(f'Error:{str(e)}')

    # Save file as CSV
    df = pd.DataFrame(all_data)
    df.to_csv('cazooCarsDataset.csv', index=False, encoding='utf-8')
    print('Data Saved in cazooCarsDataset.csv!')

# %% [markdown]
# ## 3. Get Data

# %%
cazoo_web_scraping(pages=1000)
# Out:
# Error:invalid literal for int() with base 10: '46+'
# Error:invalid literal for int() with base 10: '72.8+'
# Error:invalid literal for int() with base 10: '41.2+'
# Error:invalid literal for int() with base 10: '68+'
# Error:invalid literal for int() with base 10: '103.3+'
# Error:invalid literal for int() with base 10: '67.6+'
# Error:invalid literal for int() with base 10: '99.4+'
# Error:invalid literal for int() with base 10: '110.3+'
# Error:invalid literal for int() with base 10: '100.9+'
# Error:invalid literal for int() with base 10: '103+'
# Error:invalid literal for int() with base 10: '49.2+'
# Error:invalid literal for int() with base 10: '9.2+'
# Error:invalid literal for int() with base 10: '12.6+'
# Error:invalid literal for int() with base 10: '122.4+'
# Error:invalid literal for int() with base 10: '53.5+'
# Error:invalid literal for int() with base 10: '123+'
# Error:invalid literal for int() with base 10: '19.8+'
# Error:invalid literal for int() with base 10: '87+'
# Error:invalid literal for int() with base 10: '83.5'
# Error:invalid literal for int() with base 10: '97.9+'
# Error:invalid literal for int() with base 10: '56.3+'
# Error:invalid literal for int() with base 10: '41.7'
# Error:invalid literal for int() with base 10: '78.5'
# Error:invalid literal for int() with base 10: '156.7+'
# Error:invalid literal for int() with base 10: '167.5+'
# Error:invalid literal for int() with base 10: '86.8'
# Error:invalid literal for int() with base 10: '93+'
# Error:invalid literal for int() with base 10: '68.1'
# Error:invalid literal for int() with base 10: '66.8+'
# Error:invalid literal for int() with base 10: '75+'
# Error:invalid literal for int() with base 10: '70.1+'
# Error:invalid literal for int() with base 10: '1.4+'
# Error:invalid literal for int() with base 10: '52.9+'
# Error:invalid literal for int() with base 10: '9.4+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '160.1+'
# Error:invalid literal for int() with base 10: '84.7'
# Error:invalid literal for int() with base 10: '36.8+'
# Error:invalid literal for int() with base 10: '34.1+'
# Error:invalid literal for int() with base 10: '101.9+'
# Error:invalid literal for int() with base 10: '154.3+'
# Error:invalid literal for int() with base 10: '23.6'
# Error:invalid literal for int() with base 10: '52.8+'
# Error:invalid literal for int() with base 10: '68.9+'
# Error:invalid literal for int() with base 10: '89.2+'
# Error:invalid literal for int() with base 10: '10.9+'
# Error:invalid literal for int() with base 10: '85.6+'
# Error:invalid literal for int() with base 10: '75.2+'
# Error:invalid literal for int() with base 10: '18.3'
# Error:invalid literal for int() with base 10: '69.8+'
# Error:invalid literal for int() with base 10: '107.3'
# Error:invalid literal for int() with base 10: '50.2+'
# Error:invalid literal for int() with base 10: '46.5+'
# Error:invalid literal for int() with base 10: '149.9+'
# Error:invalid literal for int() with base 10: '3.6+'
# Error:invalid literal for int() with base 10: '111.3+'
# Error:invalid literal for int() with base 10: '63.8+'
# Error:invalid literal for int() with base 10: '12.7+'
# Error:invalid literal for int() with base 10: '56.3+'
# Error:invalid literal for int() with base 10: '66.6+'
# Error:invalid literal for int() with base 10: '23.3'
# Error:invalid literal for int() with base 10: '99.5'
# Error:invalid literal for int() with base 10: '111.4+'
# Error:invalid literal for int() with base 10: '62.1+'
# Error:invalid literal for int() with base 10: '3.5+'
# Error:invalid literal for int() with base 10: '74.8'
# Error:invalid literal for int() with base 10: '135.8+'
# Error:invalid literal for int() with base 10: '60.8+'
# Error:invalid literal for int() with base 10: '104.6+'
# Error:invalid literal for int() with base 10: '10.6+'
# Error:invalid literal for int() with base 10: '10.8+'
# Error:invalid literal for int() with base 10: '157+'
# Error:invalid literal for int() with base 10: '105.8+'
# Error:invalid literal for int() with base 10: '35.8+'
# Error:invalid literal for int() with base 10: '96.5+'
# Error:invalid literal for int() with base 10: '52+'
# Error:invalid literal for int() with base 10: '43.3+'
# Error:invalid literal for int() with base 10: '64.7+'
# Error:invalid literal for int() with base 10: '127.9+'
# Error:invalid literal for int() with base 10: '35.4+'
# Error:invalid literal for int() with base 10: '19.9'
# Error:invalid literal for int() with base 10: '62.5+'
# Error:invalid literal for int() with base 10: '121+'
# Error:invalid literal for int() with base 10: '5.3+'
# Error:invalid literal for int() with base 10: '71.6+'
# Error:invalid literal for int() with base 10: '21.9+'
# Error:invalid literal for int() with base 10: '79.5'
# Error:invalid literal for int() with base 10: '4.8+'
# Error:invalid literal for int() with base 10: '35.4+'
# Error:invalid literal for int() with base 10: '45.5+'
# Error:invalid literal for int() with base 10: '113.1+'
# Error:invalid literal for int() with base 10: '125.6+'
# Error:invalid literal for int() with base 10: '58.9+'
# Error:invalid literal for int() with base 10: '79.9+'
# Error:invalid literal for int() with base 10: '1.5'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '59.1+'
# Error:invalid literal for int() with base 10: '52.5+'
# Error:invalid literal for int() with base 10: '73.9+'
# Error:invalid literal for int() with base 10: '108.4+'
# Error:invalid literal for int() with base 10: '2.3+'
# Error:invalid literal for int() with base 10: '91.5'
# Error:invalid literal for int() with base 10: '60.1+'
# Error:invalid literal for int() with base 10: '98.9+'
# Error:invalid literal for int() with base 10: '70.9+'
# Error:invalid literal for int() with base 10: '177.9'
# Error:invalid literal for int() with base 10: '49.4+'
# Error:invalid literal for int() with base 10: '77.9+'
# Error:invalid literal for int() with base 10: '81.8+'
# Error:invalid literal for int() with base 10: '48.2+'
# Error:invalid literal for int() with base 10: '91.8+'
# Error:invalid literal for int() with base 10: '131.5'
# Error:invalid literal for int() with base 10: '63.1+'
# Error:invalid literal for int() with base 10: '111.3'
# Error:invalid literal for int() with base 10: '48.9+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '9.3+'
# Error:invalid literal for int() with base 10: '22+'
# Error:invalid literal for int() with base 10: '17.5+'
# Error:invalid literal for int() with base 10: '96.9+'
# Error:invalid literal for int() with base 10: '12.8+'
# Error:invalid literal for int() with base 10: '109.8+'
# Error:invalid literal for int() with base 10: '78.1'
# Error:invalid literal for int() with base 10: '6.3+'
# Error:invalid literal for int() with base 10: '22.3+'
# Error:invalid literal for int() with base 10: '94+'
# Error:invalid literal for int() with base 10: '32.3+'
# Error:invalid literal for int() with base 10: '17.4+'
# Error:invalid literal for int() with base 10: '105.3+'
# Error:invalid literal for int() with base 10: '71+'
# Error:invalid literal for int() with base 10: '12.4+'
# Error:invalid literal for int() with base 10: '104.8+'
# Error:invalid literal for int() with base 10: '83.4+'
# Error:invalid literal for int() with base 10: '121.4+'
# Error:invalid literal for int() with base 10: '170.3+'
# Error:invalid literal for int() with base 10: '118.6+'
# Error:invalid literal for int() with base 10: '82.5+'
# Error:invalid literal for int() with base 10: '25.3+'
# Error:invalid literal for int() with base 10: '72.3+'
# Error:invalid literal for int() with base 10: '18.9+'
# Error:invalid literal for int() with base 10: '96.5'
# Error:invalid literal for int() with base 10: '17.9+'
# Error:invalid literal for int() with base 10: '41.5'
# Error:invalid literal for int() with base 10: '74.6+'
# Error:invalid literal for int() with base 10: '82.5+'
# Error:invalid literal for int() with base 10: '60.1+'
# Error:invalid literal for int() with base 10: '102.6+'
# Error:invalid literal for int() with base 10: '18.5+'
# Error:invalid literal for int() with base 10: '91+'
# Error:invalid literal for int() with base 10: '122.1+'
# Error:invalid literal for int() with base 10: '36.1'
# Error:invalid literal for int() with base 10: '44.9+'
# Error:invalid literal for int() with base 10: '11.5+'
# Error:invalid literal for int() with base 10: '109.4+'
# Error:invalid literal for int() with base 10: '15.5+'
# Error:invalid literal for int() with base 10: '78.2+'
# Error:invalid literal for int() with base 10: '50.5+'
# Error:invalid literal for int() with base 10: '59.1+'
# Error:invalid literal for int() with base 10: '9.7+'
# Error:invalid literal for int() with base 10: '77.9+'
# Error:invalid literal for int() with base 10: '94.2+'
# Error:invalid literal for int() with base 10: '60+'
# Error:invalid literal for int() with base 10: '95.8+'
# Error:invalid literal for int() with base 10: '76.9'
# Error:invalid literal for int() with base 10: '26.2+'
# Error:invalid literal for int() with base 10: '51.1+'
# Error:invalid literal for int() with base 10: '6.3+'
# Error:invalid literal for int() with base 10: '3.2+'
# Error:invalid literal for int() with base 10: '129+'
# Error:invalid literal for int() with base 10: '22.9+'
# Error:invalid literal for int() with base 10: '65.8+'
# Error:invalid literal for int() with base 10: '4.4+'
# Error:invalid literal for int() with base 10: '115.3+'
# Error:invalid literal for int() with base 10: '46.5+'
# Error:invalid literal for int() with base 10: '114.9+'
# Error:invalid literal for int() with base 10: '34.8+'
# Error:invalid literal for int() with base 10: '12.7+'
# Error:invalid literal for int() with base 10: '56+'
# Error:invalid literal for int() with base 10: '46+'
# Error:invalid literal for int() with base 10: '122+'
# Error:invalid literal for int() with base 10: '30+'
# Error:invalid literal for int() with base 10: '12.1+'
# Error:invalid literal for int() with base 10: '31.4+'
# Error:invalid literal for int() with base 10: '62.3+'
# Error:invalid literal for int() with base 10: '43.3+'
# Error:invalid literal for int() with base 10: '53.7+'
# Error:invalid literal for int() with base 10: '32.1+'
# Error:invalid literal for int() with base 10: '130.1+'
# Error:invalid literal for int() with base 10: '25.1+'
# Error:invalid literal for int() with base 10: '100.6+'
# Error:invalid literal for int() with base 10: '59.3+'
# Error:invalid literal for int() with base 10: '30+'
# Error:invalid literal for int() with base 10: '68.5+'
# Error:invalid literal for int() with base 10: '26.8+'
# Error:invalid literal for int() with base 10: '73.7+'
# Error:invalid literal for int() with base 10: '2.3+'
# Error:invalid literal for int() with base 10: '91.7+'
# Error:invalid literal for int() with base 10: '93.3'
# Error:invalid literal for int() with base 10: '53.1+'
# Error:invalid literal for int() with base 10: '41.2+'
# Error:invalid literal for int() with base 10: '39.8+'
# Error:invalid literal for int() with base 10: '12.2+'
# Error:invalid literal for int() with base 10: '121.8+'
# Error:invalid literal for int() with base 10: '30.1+'
# Error:invalid literal for int() with base 10: '2+'
# Error:invalid literal for int() with base 10: '47.5+'
# Error:invalid literal for int() with base 10: '9.7+'
# Error:invalid literal for int() with base 10: '12.4+'
# Error:invalid literal for int() with base 10: '25.9+'
# Error:invalid literal for int() with base 10: '43.7+'
# Error:invalid literal for int() with base 10: '73.4'
# Error:invalid literal for int() with base 10: '23.4+'
# Error:invalid literal for int() with base 10: '68.3+'
# Error:invalid literal for int() with base 10: '65.5+'
# Error:invalid literal for int() with base 10: '45.6'
# Error:invalid literal for int() with base 10: '35.4+'
# Error:invalid literal for int() with base 10: '4.8+'
# Error:invalid literal for int() with base 10: '1.9+'
# Error:invalid literal for int() with base 10: '129.2+'
# Error:invalid literal for int() with base 10: '40.4+'
# Error:invalid literal for int() with base 10: '36.9+'
# Error:invalid literal for int() with base 10: '73.3+'
# Error:invalid literal for int() with base 10: '22.1+'
# Error:invalid literal for int() with base 10: '84.6+'
# Error:invalid literal for int() with base 10: '31.8+'
# Error:invalid literal for int() with base 10: '118.6+'
# Error:invalid literal for int() with base 10: '23.7+'
# Error:invalid literal for int() with base 10: '44.1+'
# Error:invalid literal for int() with base 10: '62.7+'
# Error:invalid literal for int() with base 10: '4.1'
# Error:invalid literal for int() with base 10: '31.4+'
# Error:invalid literal for int() with base 10: '81.6+'
# Error:invalid literal for int() with base 10: '39.2+'
# Error:invalid literal for int() with base 10: '63.5'
# Error:invalid literal for int() with base 10: '66.4'
# Error:invalid literal for int() with base 10: '40.1+'
# Error:invalid literal for int() with base 10: '16.5+'
# Error:invalid literal for int() with base 10: '60.6+'
# Error:invalid literal for int() with base 10: '52.5'
# Error:invalid literal for int() with base 10: '58.9+'
# Error:invalid literal for int() with base 10: '35+'
# Error:invalid literal for int() with base 10: '40.8+'
# Error:invalid literal for int() with base 10: '12.3+'
# Error:invalid literal for int() with base 10: '45+'
# Error:invalid literal for int() with base 10: '5.1+'
# Error:invalid literal for int() with base 10: '4.7+'
# Error:invalid literal for int() with base 10: '2+'
# Error:invalid literal for int() with base 10: '47+'
# Error:invalid literal for int() with base 10: '81.9+'
# Error:invalid literal for int() with base 10: '12.4'
# Error:invalid literal for int() with base 10: '49.4'
# Error:invalid literal for int() with base 10: '92.1'
# Error:invalid literal for int() with base 10: '47.5'
# Error:invalid literal for int() with base 10: '76.5+'
# Error:invalid literal for int() with base 10: '52.8+'
# Error:invalid literal for int() with base 10: '34.1+'
# Error:invalid literal for int() with base 10: '45.7+'
# Error:invalid literal for int() with base 10: '1+'
# Error:invalid literal for int() with base 10: '11+'
# Error:invalid literal for int() with base 10: '88.4+'
# Error:invalid literal for int() with base 10: '6.7+'
# Error:invalid literal for int() with base 10: '88.7+'
# Error:invalid literal for int() with base 10: '38+'
# Error:invalid literal for int() with base 10: '56.6+'
# Error:invalid literal for int() with base 10: '87.2+'
# Error:invalid literal for int() with base 10: '25.8+'
# Error:invalid literal for int() with base 10: '123.2+'
# Error:invalid literal for int() with base 10: '122.7+'
# Error:invalid literal for int() with base 10: '43.4+'
# Error:invalid literal for int() with base 10: '35.3+'
# Error:invalid literal for int() with base 10: '33.2+'
# Error:invalid literal for int() with base 10: '52.5'
# Error:invalid literal for int() with base 10: '23.1+'
# Error:invalid literal for int() with base 10: '3+'
# Error:invalid literal for int() with base 10: '85.4+'
# Error:invalid literal for int() with base 10: '47.8+'
# Error:invalid literal for int() with base 10: '1.2+'
# Error:invalid literal for int() with base 10: '67+'
# Error:invalid literal for int() with base 10: '10.3+'
# Error:invalid literal for int() with base 10: '52.1+'
# Error:invalid literal for int() with base 10: '83.5+'
# Error:invalid literal for int() with base 10: '129.7+'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '1.2+'
# Error:invalid literal for int() with base 10: '82.1'
# Error:invalid literal for int() with base 10: '32.3+'
# Error:invalid literal for int() with base 10: '60.6+'
# Error:invalid literal for int() with base 10: '19.1+'
# Error:invalid literal for int() with base 10: '22.7+'
# Error:invalid literal for int() with base 10: '3.2+'
# Error:invalid literal for int() with base 10: '8.5+'
# Error:invalid literal for int() with base 10: '104+'
# Error:invalid literal for int() with base 10: '5.7+'
# Error:invalid literal for int() with base 10: '50.9+'
# Error:invalid literal for int() with base 10: '111.6+'
# Error:invalid literal for int() with base 10: '5.8+'
# Error:invalid literal for int() with base 10: '40.6+'
# Error:invalid literal for int() with base 10: '102.1+'
# Error:invalid literal for int() with base 10: '62.8'
# Error:invalid literal for int() with base 10: '10.5'
# Error:invalid literal for int() with base 10: '41+'
# Error:invalid literal for int() with base 10: '35.2'
# Error:invalid literal for int() with base 10: '35.8+'
# Error:invalid literal for int() with base 10: '7.8+'
# Error:invalid literal for int() with base 10: '18.2+'
# Error:invalid literal for int() with base 10: '89.4+'
# Error:invalid literal for int() with base 10: '34.4+'
# Error:invalid literal for int() with base 10: '11.7+'
# Error:invalid literal for int() with base 10: '108.2'
# Error:invalid literal for int() with base 10: '32.8+'
# Error:invalid literal for int() with base 10: '4.1+'
# Error:invalid literal for int() with base 10: '1.6+'
# Error:invalid literal for int() with base 10: '46.4+'
# Error:invalid literal for int() with base 10: '51+'
# Error:invalid literal for int() with base 10: '54.4+'
# Error:invalid literal for int() with base 10: '72.9+'
# Error:invalid literal for int() with base 10: '44+'
# Error:invalid literal for int() with base 10: '4+'
# Error:invalid literal for int() with base 10: '115.2+'
# Error:invalid literal for int() with base 10: '57.5+'
# Error:invalid literal for int() with base 10: '7.2'
# Error:invalid literal for int() with base 10: '57.6+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '90.9+'
# Error:invalid literal for int() with base 10: '28.3+'
# Error:invalid literal for int() with base 10: '2.8+'
# Error:invalid literal for int() with base 10: '35.9+'
# Error:invalid literal for int() with base 10: '39.7+'
# Error:invalid literal for int() with base 10: '93.1+'
# Error:invalid literal for int() with base 10: '53.6+'
# Error:invalid literal for int() with base 10: '4.6+'
# Error:invalid literal for int() with base 10: '26+'
# Error:invalid literal for int() with base 10: '1.1+'
# Error:invalid literal for int() with base 10: '47.9+'
# Error:invalid literal for int() with base 10: '12.6+'
# Error:invalid literal for int() with base 10: '29.4+'
# Error:invalid literal for int() with base 10: '36.4+'
# Error:invalid literal for int() with base 10: '93.1+'
# Error:invalid literal for int() with base 10: '116.4'
# Error:invalid literal for int() with base 10: '16.3'
# Error:invalid literal for int() with base 10: '20.8+'
# Error:invalid literal for int() with base 10: '107.1+'
# Error:invalid literal for int() with base 10: '58.2'
# Error:invalid literal for int() with base 10: '96.7+'
# Error:invalid literal for int() with base 10: '55.8+'
# Error:invalid literal for int() with base 10: '7+'
# Error:invalid literal for int() with base 10: '37.4+'
# Error:invalid literal for int() with base 10: '28.5'
# Error:invalid literal for int() with base 10: '44.6+'
# Error:invalid literal for int() with base 10: '67.3+'
# Error:invalid literal for int() with base 10: '98.6'
# Error:invalid literal for int() with base 10: '57.9+'
# Error:invalid literal for int() with base 10: '52.3+'
# Error:invalid literal for int() with base 10: '61.8+'
# Error:invalid literal for int() with base 10: '18.3+'
# Error:invalid literal for int() with base 10: '18+'
# Error:invalid literal for int() with base 10: '37.1+'
# Error:invalid literal for int() with base 10: '76.9+'
# Error:invalid literal for int() with base 10: '10.4+'
# Error:invalid literal for int() with base 10: '88.5+'
# Error:invalid literal for int() with base 10: '41.8+'
# Error:invalid literal for int() with base 10: '34.8'
# Error:invalid literal for int() with base 10: '75.4+'
# Error:invalid literal for int() with base 10: '92+'
# Error:invalid literal for int() with base 10: '7.3+'
# Error:invalid literal for int() with base 10: '25.5'
# Error:invalid literal for int() with base 10: '34.9+'
# Error:invalid literal for int() with base 10: '14+'
# Error:invalid literal for int() with base 10: '49.9+'
# Error:invalid literal for int() with base 10: '19+'
# Error:invalid literal for int() with base 10: '7.3+'
# Error:invalid literal for int() with base 10: '45.9+'
# Error:invalid literal for int() with base 10: '14.2+'
# Error:invalid literal for int() with base 10: '112.8+'
# Error:invalid literal for int() with base 10: '68.1+'
# Error:invalid literal for int() with base 10: '19.5+'
# Error:invalid literal for int() with base 10: '101.4+'
# Error:invalid literal for int() with base 10: '50.3+'
# Error:invalid literal for int() with base 10: '86.5+'
# Error:invalid literal for int() with base 10: '46.7+'
# Error:invalid literal for int() with base 10: '70.3+'
# Error:invalid literal for int() with base 10: '24.3+'
# Error:invalid literal for int() with base 10: '13.2+'
# Error:invalid literal for int() with base 10: '12.2+'
# Error:invalid literal for int() with base 10: '103.7+'
# Error:invalid literal for int() with base 10: '22.6+'
# Error:invalid literal for int() with base 10: '63.7+'
# Error:invalid literal for int() with base 10: '4.3+'
# Error:invalid literal for int() with base 10: '28.2+'
# Error:invalid literal for int() with base 10: '93.2'
# Error:invalid literal for int() with base 10: '21.8+'
# Error:invalid literal for int() with base 10: '54.5'
# Error:invalid literal for int() with base 10: '59.5+'
# Error:invalid literal for int() with base 10: '18.4+'
# Error:invalid literal for int() with base 10: '6.3+'
# Error:invalid literal for int() with base 10: '34.6+'
# Error:invalid literal for int() with base 10: '51.5+'
# Error:invalid literal for int() with base 10: '32.9+'
# Error:invalid literal for int() with base 10: '18.7+'
# Error:invalid literal for int() with base 10: '48.4+'
# Error:invalid literal for int() with base 10: '3.1+'
# Error:invalid literal for int() with base 10: '39.6+'
# Error:invalid literal for int() with base 10: '4.7+'
# Error:invalid literal for int() with base 10: '4+'
# Error:invalid literal for int() with base 10: '1.2+'
# Error:invalid literal for int() with base 10: '25.6+'
# Error:invalid literal for int() with base 10: '126.5'
# Error:invalid literal for int() with base 10: '32.6+'
# Error:invalid literal for int() with base 10: '94.6+'
# Error:invalid literal for int() with base 10: '90.4+'
# Error:invalid literal for int() with base 10: '25.2+'
# Error:invalid literal for int() with base 10: '27.2+'
# Error:invalid literal for int() with base 10: '73.9+'
# Error:invalid literal for int() with base 10: '29.6+'
# Error:invalid literal for int() with base 10: '68.9+'
# Error:invalid literal for int() with base 10: '50.1+'
# Error:invalid literal for int() with base 10: '14.8+'
# Error:invalid literal for int() with base 10: '56.6'
# Error:invalid literal for int() with base 10: '42.6+'
# Error:invalid literal for int() with base 10: '10.3+'
# Error:invalid literal for int() with base 10: '10+'
# Error:invalid literal for int() with base 10: '34.4+'
# Error:invalid literal for int() with base 10: '50.3+'
# Error:invalid literal for int() with base 10: '59.5'
# Error:invalid literal for int() with base 10: '93.4+'
# Error:invalid literal for int() with base 10: '38.7+'
# Error:invalid literal for int() with base 10: '24.1+'
# Error:invalid literal for int() with base 10: '26.5+'
# Error:invalid literal for int() with base 10: '91.3+'
# Error:invalid literal for int() with base 10: '44.9+'
# Error:invalid literal for int() with base 10: '78.1+'
# Error:invalid literal for int() with base 10: '63.4+'
# Error:invalid literal for int() with base 10: '13.9+'
# Error:invalid literal for int() with base 10: '64.5'
# Error:invalid literal for int() with base 10: '1.2+'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '17.1+'
# Error:invalid literal for int() with base 10: '73.8'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '4.9+'
# Error:invalid literal for int() with base 10: '116.6+'
# Error:invalid literal for int() with base 10: '25.9+'
# Error:invalid literal for int() with base 10: '95.5'
# Error:invalid literal for int() with base 10: '2.1+'
# Error:invalid literal for int() with base 10: '22.2+'
# Error:invalid literal for int() with base 10: '87.1'
# Error:invalid literal for int() with base 10: '44.1+'
# Error:invalid literal for int() with base 10: '29.2'
# Error:invalid literal for int() with base 10: '96+'
# Error:invalid literal for int() with base 10: '50.5+'
# Error:invalid literal for int() with base 10: '50+'
# Error:invalid literal for int() with base 10: '32.4+'
# Error:invalid literal for int() with base 10: '63.6+'
# Error:invalid literal for int() with base 10: '52.5+'
# Error:invalid literal for int() with base 10: '50.9+'
# Error:invalid literal for int() with base 10: '42.6+'
# Error:invalid literal for int() with base 10: '64.8+'
# Error:invalid literal for int() with base 10: '49+'
# Error:invalid literal for int() with base 10: '109.4+'
# Error:invalid literal for int() with base 10: '57.6+'
# Error:invalid literal for int() with base 10: '25.2+'
# Error:invalid literal for int() with base 10: '95.8+'
# Error:invalid literal for int() with base 10: '29.4+'
# Error:invalid literal for int() with base 10: '66.6'
# Error:invalid literal for int() with base 10: '44.2+'
# Error:invalid literal for int() with base 10: '40.2+'
# Error:invalid literal for int() with base 10: '30.4+'
# Error:invalid literal for int() with base 10: '61.3'
# Error:invalid literal for int() with base 10: '18+'
# Error:invalid literal for int() with base 10: '42.6+'
# Error:invalid literal for int() with base 10: '44.1+'
# Error:invalid literal for int() with base 10: '36.6+'
# Error:invalid literal for int() with base 10: '8+'
# Error:invalid literal for int() with base 10: '91.2+'
# Error:invalid literal for int() with base 10: '83+'
# Error:invalid literal for int() with base 10: '27.6+'
# Error:invalid literal for int() with base 10: '42.1+'
# Error:invalid literal for int() with base 10: '33.9+'
# Error:invalid literal for int() with base 10: '42.5+'
# Error:invalid literal for int() with base 10: '84.3+'
# Error:invalid literal for int() with base 10: '76.1+'
# Error:invalid literal for int() with base 10: '43.2'
# Error:invalid literal for int() with base 10: '23.4+'
# Error:invalid literal for int() with base 10: '71.3+'
# Error:invalid literal for int() with base 10: '62.1+'
# Error:invalid literal for int() with base 10: '20.4+'
# Error:invalid literal for int() with base 10: '50.5'
# Error:invalid literal for int() with base 10: '8.9'
# Error:invalid literal for int() with base 10: '29.7+'
# Error:invalid literal for int() with base 10: '99.2+'
# Error:invalid literal for int() with base 10: '1.5+'
# Error:invalid literal for int() with base 10: '60.3'
# Error:invalid literal for int() with base 10: '78.1+'
# Error:invalid literal for int() with base 10: '79.6+'
# Error:invalid literal for int() with base 10: '13.1+'
# Error:invalid literal for int() with base 10: '37.2+'
# Error:invalid literal for int() with base 10: '19.8'
# Error:invalid literal for int() with base 10: '23.4+'
# Error:invalid literal for int() with base 10: '26.7'
# Error:invalid literal for int() with base 10: '27.1+'
# Error:invalid literal for int() with base 10: '17.2+'
# Error:invalid literal for int() with base 10: '61.8+'
# Error:invalid literal for int() with base 10: '21.8+'
# Error:invalid literal for int() with base 10: '53.2+'
# Error:invalid literal for int() with base 10: '18+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '6.2+'
# Error:invalid literal for int() with base 10: '1.5+'
# Error:invalid literal for int() with base 10: '21.6+'
# Error:invalid literal for int() with base 10: '26.2+'
# Error:invalid literal for int() with base 10: '63.8+'
# Error:invalid literal for int() with base 10: '25.8+'
# Error:invalid literal for int() with base 10: '8.6+'
# Error:invalid literal for int() with base 10: '45.2+'
# Error:invalid literal for int() with base 10: '24.4+'
# Error:invalid literal for int() with base 10: '4.9+'
# Error:invalid literal for int() with base 10: '15.4+'
# Error:invalid literal for int() with base 10: '96.3+'
# Error:invalid literal for int() with base 10: '78.1+'
# Error:invalid literal for int() with base 10: '37.1+'
# Error:invalid literal for int() with base 10: '44.7'
# Error:invalid literal for int() with base 10: '1.9+'
# Error:invalid literal for int() with base 10: '87.3+'
# Error:invalid literal for int() with base 10: '29.3+'
# Error:invalid literal for int() with base 10: '78.2+'
# Error:invalid literal for int() with base 10: '11+'
# Error:invalid literal for int() with base 10: '58.2'
# Error:invalid literal for int() with base 10: '117.5'
# Error:invalid literal for int() with base 10: '19.9+'
# Error:invalid literal for int() with base 10: '33+'
# Error:invalid literal for int() with base 10: '49.3+'
# Error:invalid literal for int() with base 10: '24.6+'
# Error:invalid literal for int() with base 10: '94.2+'
# Error:invalid literal for int() with base 10: '118.2+'
# Error:invalid literal for int() with base 10: '67.6+'
# Error:invalid literal for int() with base 10: '2.5+'
# Error:invalid literal for int() with base 10: '33.3+'
# Error:invalid literal for int() with base 10: '53.4+'
# Error:invalid literal for int() with base 10: '49.1+'
# Error:invalid literal for int() with base 10: '17.4+'
# Error:invalid literal for int() with base 10: '48.3+'
# Error:invalid literal for int() with base 10: '11.4'
# Error:invalid literal for int() with base 10: '32.4+'
# Error:invalid literal for int() with base 10: '94.2+'
# Error:invalid literal for int() with base 10: '90.1+'
# Error:invalid literal for int() with base 10: '35.7+'
# Error:invalid literal for int() with base 10: '30.7+'
# Error:invalid literal for int() with base 10: '22.7+'
# Error:invalid literal for int() with base 10: '4.3+'
# Error:invalid literal for int() with base 10: '32.1+'
# Error:invalid literal for int() with base 10: '1.5+'
# Error:invalid literal for int() with base 10: '20.5+'
# Error:invalid literal for int() with base 10: '48.8+'
# Error:invalid literal for int() with base 10: '10.1+'
# Error:invalid literal for int() with base 10: '43.8+'
# Error:invalid literal for int() with base 10: '33.3+'
# Error:invalid literal for int() with base 10: '55.2+'
# Error:invalid literal for int() with base 10: '13.5+'
# Error:invalid literal for int() with base 10: '12.2+'
# Error:invalid literal for int() with base 10: '44.5'
# Error:invalid literal for int() with base 10: '64.3+'
# Error:invalid literal for int() with base 10: '2.1+'
# Error:invalid literal for int() with base 10: '34.4+'
# Error:invalid literal for int() with base 10: '26.6+'
# Error:invalid literal for int() with base 10: '1.7+'
# Error:invalid literal for int() with base 10: '62.6+'
# Error:invalid literal for int() with base 10: '20.3+'
# Error:invalid literal for int() with base 10: '62.3+'
# Error:invalid literal for int() with base 10: '82.4+'
# Error:invalid literal for int() with base 10: '47.2+'
# Error:invalid literal for int() with base 10: '9+'
# Error:invalid literal for int() with base 10: '1.1+'
# Error:invalid literal for int() with base 10: '103.1+'
# Error:invalid literal for int() with base 10: '26.7+'
# Error:invalid literal for int() with base 10: '46.6+'
# Error:invalid literal for int() with base 10: '48.2+'
# Error:invalid literal for int() with base 10: '105+'
# Error:invalid literal for int() with base 10: '74.5+'
# Error:invalid literal for int() with base 10: '65+'
# Error:invalid literal for int() with base 10: '4.4+'
# Error:invalid literal for int() with base 10: '122.2+'
# Error:invalid literal for int() with base 10: '48.2+'
# Error:invalid literal for int() with base 10: '43.5+'
# Error:invalid literal for int() with base 10: '13.7+'
# Error:invalid literal for int() with base 10: '21.9+'
# Error:invalid literal for int() with base 10: '11.2+'
# Error:invalid literal for int() with base 10: '11.6+'
# Error:invalid literal for int() with base 10: '59.2+'
# Error:invalid literal for int() with base 10: '83.6+'
# Error:invalid literal for int() with base 10: '63.7+'
# Error:invalid literal for int() with base 10: '39.5+'
# Error:invalid literal for int() with base 10: '56.5+'
# Error:invalid literal for int() with base 10: '11.2+'
# Error:invalid literal for int() with base 10: '4.1+'
# Error:invalid literal for int() with base 10: '28.3+'
# Error:invalid literal for int() with base 10: '46.1+'
# Error:invalid literal for int() with base 10: '6.8+'
# Error:invalid literal for int() with base 10: '24.3+'
# Error:invalid literal for int() with base 10: '56.7+'
# Error:invalid literal for int() with base 10: '31.5+'
# Error:invalid literal for int() with base 10: '61.2'
# Error:invalid literal for int() with base 10: '54.5+'
# Error:invalid literal for int() with base 10: '47.6+'
# Error:invalid literal for int() with base 10: '68.5+'
# Error:invalid literal for int() with base 10: '24.3+'
# Error:invalid literal for int() with base 10: '73.4+'
# Error:invalid literal for int() with base 10: '14.3+'
# Error:invalid literal for int() with base 10: '41.8+'
# Error:invalid literal for int() with base 10: '17.3+'
# Error:invalid literal for int() with base 10: '53.3+'
# Error:invalid literal for int() with base 10: '79.9'
# Error:invalid literal for int() with base 10: '88.4+'
# Error:invalid literal for int() with base 10: '5.7+'
# Error:invalid literal for int() with base 10: '44.1+'
# Error:invalid literal for int() with base 10: '114.2+'
# Error:invalid literal for int() with base 10: '93.5+'
# Error:invalid literal for int() with base 10: '73.3+'
# Error:invalid literal for int() with base 10: '16.5+'
# Error:invalid literal for int() with base 10: '25.4+'
# Error:invalid literal for int() with base 10: '90+'
# Error:invalid literal for int() with base 10: '43+'
# Error:invalid literal for int() with base 10: '66.5+'
# Error:invalid literal for int() with base 10: '10.9+'
# Error:invalid literal for int() with base 10: '25+'
# Error:invalid literal for int() with base 10: '18.2+'
# Error:invalid literal for int() with base 10: '101.9+'
# Error:invalid literal for int() with base 10: '30.1+'
# Error:invalid literal for int() with base 10: '25.3+'
# Error:invalid literal for int() with base 10: '13.9+'
# Error:invalid literal for int() with base 10: '28.8+'
# Error:invalid literal for int() with base 10: '18.9+'
# Error:invalid literal for int() with base 10: '31.6+'
# Error:invalid literal for int() with base 10: '83.2+'
# Error:invalid literal for int() with base 10: '65.1+'
# Error:invalid literal for int() with base 10: '32.5+'
# Error:invalid literal for int() with base 10: '7.1+'
# Error:invalid literal for int() with base 10: '61.6+'
# Error:invalid literal for int() with base 10: '19.6+'
# Error:invalid literal for int() with base 10: '28.4+'
# Error:invalid literal for int() with base 10: '44.1+'
# Error:invalid literal for int() with base 10: '42.2'
# Error:invalid literal for int() with base 10: '4.9'
# Error:invalid literal for int() with base 10: '38.6+'
# Error:invalid literal for int() with base 10: '52.2+'
# Error:invalid literal for int() with base 10: '24.6+'
# Error:invalid literal for int() with base 10: '45.1+'
# Error:invalid literal for int() with base 10: '29.5+'
# Error:invalid literal for int() with base 10: '15.1+'
# Error:invalid literal for int() with base 10: '14.7+'
# Error:invalid literal for int() with base 10: '104.7+'
# Error:invalid literal for int() with base 10: '35.3+'
# Error:invalid literal for int() with base 10: '14.4+'
# Error:invalid literal for int() with base 10: '89.9+'
# Error:invalid literal for int() with base 10: '19+'
# Error:invalid literal for int() with base 10: '45.5+'
# Error:invalid literal for int() with base 10: '72.3+'
# Error:invalid literal for int() with base 10: '2.5+'
# Error:invalid literal for int() with base 10: '32.4+'
# Error:invalid literal for int() with base 10: '156.3+'
# Error:invalid literal for int() with base 10: '36.9+'
# Error:invalid literal for int() with base 10: '127.8+'
# Error:invalid literal for int() with base 10: '30.2'
# Error:invalid literal for int() with base 10: '104.6'
# Error:invalid literal for int() with base 10: '16.1'
# Error:invalid literal for int() with base 10: '81.1+'
# Error:invalid literal for int() with base 10: '60.9+'
# Error:invalid literal for int() with base 10: '90.7+'
# Error:invalid literal for int() with base 10: '50.3+'
# Error:invalid literal for int() with base 10: '32.6+'
# Error:invalid literal for int() with base 10: '1+'
# Error:invalid literal for int() with base 10: '23.7+'
# Error:invalid literal for int() with base 10: '21.7+'
# Error:invalid literal for int() with base 10: '38.5'
# Error:invalid literal for int() with base 10: '46.5+'
# Error:invalid literal for int() with base 10: '2.7+'
# Error:invalid literal for int() with base 10: '10.2+'
# Error:invalid literal for int() with base 10: '6.8+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '1.2+'
# Error:invalid literal for int() with base 10: '58.2+'
# Error:invalid literal for int() with base 10: '53.1+'
# Error:invalid literal for int() with base 10: '126.3'
# Error:invalid literal for int() with base 10: '7.8+'
# Error:invalid literal for int() with base 10: '2.5+'
# Error:invalid literal for int() with base 10: '51.1+'
# Error:invalid literal for int() with base 10: '47.5+'
# Error:invalid literal for int() with base 10: '79.2+'
# Error:invalid literal for int() with base 10: '15.8+'
# Error:invalid literal for int() with base 10: '149.2+'
# Error:invalid literal for int() with base 10: '52.3+'
# Error:invalid literal for int() with base 10: '86.9+'
# Error:invalid literal for int() with base 10: '21.9+'
# Error:invalid literal for int() with base 10: '78.8+'
# Error:invalid literal for int() with base 10: '3.1+'
# Error:invalid literal for int() with base 10: '46.3+'
# Error:invalid literal for int() with base 10: '56.1+'
# Error:invalid literal for int() with base 10: '35.9+'
# Error:invalid literal for int() with base 10: '45.4+'
# Error:invalid literal for int() with base 10: '22+'
# Error:invalid literal for int() with base 10: '20.8+'
# Error:invalid literal for int() with base 10: '32.3+'
# Error:invalid literal for int() with base 10: '36.8+'
# Error:invalid literal for int() with base 10: '2.7+'
# Error:invalid literal for int() with base 10: '63.8+'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '15+'
# Error:invalid literal for int() with base 10: '33.2+'
# Error:invalid literal for int() with base 10: '43.5'
# Error:invalid literal for int() with base 10: '97.3+'
# Error:invalid literal for int() with base 10: '88.4+'
# Error:invalid literal for int() with base 10: '98+'
# Error:invalid literal for int() with base 10: '43.3+'
# Error:invalid literal for int() with base 10: '166.1+'
# Error:invalid literal for int() with base 10: '16.1+'
# Error:invalid literal for int() with base 10: '25.4+'
# Error:invalid literal for int() with base 10: '28+'
# Error:invalid literal for int() with base 10: '39.7+'
# Error:invalid literal for int() with base 10: '13.3+'
# Error:invalid literal for int() with base 10: '46.4+'
# Error:invalid literal for int() with base 10: '102.6+'
# Error:invalid literal for int() with base 10: '18.8+'
# Error:invalid literal for int() with base 10: '94.1+'
# Error:invalid literal for int() with base 10: '50.9+'
# Error:invalid literal for int() with base 10: '40.8+'
# Error:invalid literal for int() with base 10: '36.6+'
# Error:invalid literal for int() with base 10: '90.3+'
# Error:invalid literal for int() with base 10: '48.4+'
# Error:invalid literal for int() with base 10: '9.2+'
# Error:invalid literal for int() with base 10: '20.6+'
# Error:invalid literal for int() with base 10: '14+'
# Error:invalid literal for int() with base 10: '47.5+'
# Error:invalid literal for int() with base 10: '32.5+'
# Error:invalid literal for int() with base 10: '26.9+'
# Error:invalid literal for int() with base 10: '77.4+'
# Error:invalid literal for int() with base 10: '85.9+'
# Error:invalid literal for int() with base 10: '53.9+'
# Error:invalid literal for int() with base 10: '45.2+'
# Error:invalid literal for int() with base 10: '25.6+'
# Error:invalid literal for int() with base 10: '72.8+'
# Error:invalid literal for int() with base 10: '22.9+'
# Error:invalid literal for int() with base 10: '7.8+'
# Error:invalid literal for int() with base 10: '41+'
# Error:invalid literal for int() with base 10: '7.1+'
# Error:invalid literal for int() with base 10: '23.2+'
# Error:invalid literal for int() with base 10: '5.1+'
# Error:invalid literal for int() with base 10: '15.1+'
# Error:invalid literal for int() with base 10: '31.2+'
# Error:invalid literal for int() with base 10: '5.6+'
# Error:invalid literal for int() with base 10: '59.4+'
# Error:invalid literal for int() with base 10: '85.8'
# Error:invalid literal for int() with base 10: '41.4+'
# Error:invalid literal for int() with base 10: '42.9+'
# Error:invalid literal for int() with base 10: '9.8+'
# Error:invalid literal for int() with base 10: '70.8+'
# Error:invalid literal for int() with base 10: '31.6+'
# Error:invalid literal for int() with base 10: '24.4+'
# Error:invalid literal for int() with base 10: '12.3+'
# Error:invalid literal for int() with base 10: '60.1+'
# Error:invalid literal for int() with base 10: '41.4+'
# Error:invalid literal for int() with base 10: '34.3+'
# Error:invalid literal for int() with base 10: '54.3'
# Error:invalid literal for int() with base 10: '40+'
# Error:invalid literal for int() with base 10: '23.6+'
# Error:invalid literal for int() with base 10: '153.5+'
# Error:invalid literal for int() with base 10: '85.6+'
# Error:invalid literal for int() with base 10: '33.8+'
# Error:invalid literal for int() with base 10: '63.6+'
# Error:invalid literal for int() with base 10: '9+'
# Error:invalid literal for int() with base 10: '69.9+'
# Error:invalid literal for int() with base 10: '51.1+'
# Error:invalid literal for int() with base 10: '30.8+'
# Error:invalid literal for int() with base 10: '9.4+'
# Error:invalid literal for int() with base 10: '10.4+'
# Error:invalid literal for int() with base 10: '53.4'
# Error:invalid literal for int() with base 10: '62.1+'
# Error:invalid literal for int() with base 10: '70.8+'
# Error:invalid literal for int() with base 10: '16.8+'
# Error:invalid literal for int() with base 10: '40.4+'
# Error:invalid literal for int() with base 10: '27.9+'
# Error:invalid literal for int() with base 10: '96.4+'
# Error:invalid literal for int() with base 10: '3.2+'
# Error:invalid literal for int() with base 10: '36.6+'
# Error:invalid literal for int() with base 10: '17.2+'
# Error:invalid literal for int() with base 10: '57+'
# Error:invalid literal for int() with base 10: '33+'
# Error:invalid literal for int() with base 10: '13.8+'
# Error:invalid literal for int() with base 10: '60+'
# Error:invalid literal for int() with base 10: '53.2+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '10.1+'
# Error:invalid literal for int() with base 10: '2.1+'
# Error:invalid literal for int() with base 10: '28.9+'
# Error:invalid literal for int() with base 10: '12.6+'
# Error:invalid literal for int() with base 10: '21.6+'
# Error:invalid literal for int() with base 10: '19+'
# Error:invalid literal for int() with base 10: '43.8+'
# Error:invalid literal for int() with base 10: '73.6+'
# Error:invalid literal for int() with base 10: '98.1+'
# Error:invalid literal for int() with base 10: '23.6+'
# Error:invalid literal for int() with base 10: '57.2+'
# Error:invalid literal for int() with base 10: '43.1+'
# Error:invalid literal for int() with base 10: '10.3+'
# Error:invalid literal for int() with base 10: '37.5+'
# Error:invalid literal for int() with base 10: '31.1+'
# Error:invalid literal for int() with base 10: '16.7+'
# Error:invalid literal for int() with base 10: '39.5'
# Error:invalid literal for int() with base 10: '24.5'
# Error:invalid literal for int() with base 10: '26.7+'
# Error:invalid literal for int() with base 10: '12.8+'
# Error:invalid literal for int() with base 10: '30.5+'
# Error:invalid literal for int() with base 10: '4.9+'
# Error:invalid literal for int() with base 10: '72.1+'
# Error:invalid literal for int() with base 10: '41.6'
# Error:invalid literal for int() with base 10: '44.9+'
# Error:invalid literal for int() with base 10: '6.5+'
# Error:invalid literal for int() with base 10: '6.2+'
# Error:invalid literal for int() with base 10: '36.1'
# Error:invalid literal for int() with base 10: '57.3+'
# Error:invalid literal for int() with base 10: '91.4+'
# Error:invalid literal for int() with base 10: '12.9+'
# Error:invalid literal for int() with base 10: '90.5'
# Error:invalid literal for int() with base 10: '39.3+'
# Error:invalid literal for int() with base 10: '10.1+'
# Error:invalid literal for int() with base 10: '23.8'
# Error:invalid literal for int() with base 10: '96.3'
# Error:invalid literal for int() with base 10: '49.6+'
# Error:invalid literal for int() with base 10: '55.3+'
# Error:invalid literal for int() with base 10: '33.7+'
# Error:invalid literal for int() with base 10: '102.3+'
# Error:invalid literal for int() with base 10: '19+'
# Error:invalid literal for int() with base 10: '9.9+'
# Error:invalid literal for int() with base 10: '10.6+'
# Error:invalid literal for int() with base 10: '60+'
# Error:invalid literal for int() with base 10: '35+'
# Error:invalid literal for int() with base 10: '7.7+'
# Error:invalid literal for int() with base 10: '31+'
# Error:invalid literal for int() with base 10: '42.1+'
# Error:invalid literal for int() with base 10: '9.2+'
# Error:invalid literal for int() with base 10: '66.2+'
# Error:invalid literal for int() with base 10: '61.3+'
# Error:invalid literal for int() with base 10: '51.8+'
# Error:invalid literal for int() with base 10: '39.3+'
# Error:invalid literal for int() with base 10: '44+'
# Error:invalid literal for int() with base 10: '14.4'
# Error:invalid literal for int() with base 10: '22.3+'
# Error:invalid literal for int() with base 10: '6.6+'
# Error:invalid literal for int() with base 10: '51.2+'
# Error:invalid literal for int() with base 10: '40.5+'
# Error:invalid literal for int() with base 10: '19+'
# Error:invalid literal for int() with base 10: '119.9+'
# Error:invalid literal for int() with base 10: '50.2+'
# Error:invalid literal for int() with base 10: '105+'
# Error:invalid literal for int() with base 10: '16.3+'
# Error:invalid literal for int() with base 10: '53.1+'
# Error:invalid literal for int() with base 10: '78.6+'
# Error:invalid literal for int() with base 10: '95+'
# Error:invalid literal for int() with base 10: '9.3+'
# Error:invalid literal for int() with base 10: '27.5+'
# Error:invalid literal for int() with base 10: '52.5+'
# Error:invalid literal for int() with base 10: '33.1+'
# Error:invalid literal for int() with base 10: '38.7+'
# Error:invalid literal for int() with base 10: '58.5'
# Error:invalid literal for int() with base 10: '12.3+'
# Error:invalid literal for int() with base 10: '41.7+'
# Error:invalid literal for int() with base 10: '14+'
# Error:invalid literal for int() with base 10: '37.4+'
# Error:invalid literal for int() with base 10: '30.3+'
# Error:invalid literal for int() with base 10: '67.5'
# Error:invalid literal for int() with base 10: '16.8+'
# Error:invalid literal for int() with base 10: '85.9+'
# Error:invalid literal for int() with base 10: '80.4+'
# Error:invalid literal for int() with base 10: '72.7+'
# Error:invalid literal for int() with base 10: '92+'
# Error:invalid literal for int() with base 10: '14.7+'
# Error:invalid literal for int() with base 10: '11.1+'
# Error:invalid literal for int() with base 10: '106.1'
# Error:invalid literal for int() with base 10: '135+'
# Error:invalid literal for int() with base 10: '5.7+'
# Error:invalid literal for int() with base 10: '85.7'
# Error:invalid literal for int() with base 10: '17.3+'
# Error:invalid literal for int() with base 10: '49.1+'
# Error:invalid literal for int() with base 10: '38.5'
# Error:invalid literal for int() with base 10: '45.7+'
# Error:invalid literal for int() with base 10: '164.5+'
# Error:invalid literal for int() with base 10: '47.4+'
# Error:invalid literal for int() with base 10: '28.4+'
# Error:invalid literal for int() with base 10: '15.9+'
# Error:invalid literal for int() with base 10: '16.2+'
# Error:invalid literal for int() with base 10: '86.7+'
# Error:invalid literal for int() with base 10: '50.5+'
# Error:invalid literal for int() with base 10: '9.7+'
# Error:invalid literal for int() with base 10: '39.2+'
# Error:invalid literal for int() with base 10: '48+'
# Error:invalid literal for int() with base 10: '19.1+'
# ...
# Error:invalid literal for int() with base 10: '82.5+'
# Error:invalid literal for int() with base 10: '8+'
# Error:invalid literal for int() with base 10: '41.7+'
# Error:invalid literal for int() with base 10: '35.7+'
# Error:invalid literal for int() with base 10: '54.7+'
# Error:invalid literal for int() with base 10: '120.2+'
# Error:invalid literal for int() with base 10: '21+'
# Error:invalid literal for int() with base 10: '61.7'
# Error:invalid literal for int() with base 10: '9.4+'
# Error:invalid literal for int() with base 10: '70.5+'
# Error:invalid literal for int() with base 10: '18.1+'
# Error:invalid literal for int() with base 10: '5.5+'
# Error:invalid literal for int() with base 10: '3.5'
# Error:invalid literal for int() with base 10: '51.4+'
# Error:invalid literal for int() with base 10: '71.1+'
# Error:invalid literal for int() with base 10: '7.8+'
# Error:invalid literal for int() with base 10: '4.4+'
# Error:invalid literal for int() with base 10: '15.8'
# Error:invalid literal for int() with base 10: '65.9+'
# Error:invalid literal for int() with base 10: '95.5+'
# Error:invalid literal for int() with base 10: '104+'
# Error:invalid literal for int() with base 10: '92.9+'
# Error:invalid literal for int() with base 10: '83.6+'
# Error:invalid literal for int() with base 10: '38.1+'
# Error:invalid literal for int() with base 10: '28.9+'
# Error:invalid literal for int() with base 10: '18.3+'
# Error:invalid literal for int() with base 10: '1.5'
# Error:invalid literal for int() with base 10: '22.2+'
# Error:invalid literal for int() with base 10: '2.3+'
# Error:invalid literal for int() with base 10: '72.5+'
# Error:invalid literal for int() with base 10: '36.7+'
# Error:invalid literal for int() with base 10: '10.1+'
# Error:invalid literal for int() with base 10: '58.8+'
# Error:invalid literal for int() with base 10: '49+'
# Error:invalid literal for int() with base 10: '37.9+'
# Error:invalid literal for int() with base 10: '39.4+'
# Error:invalid literal for int() with base 10: '14.7+'
# Error:invalid literal for int() with base 10: '106.9+'
# Error:invalid literal for int() with base 10: '54.7+'
# Error:invalid literal for int() with base 10: '121.1+'
# Error:invalid literal for int() with base 10: '80.4+'
# Error:invalid literal for int() with base 10: '31.1+'
# Error:invalid literal for int() with base 10: '16.3+'
# Error:invalid literal for int() with base 10: '46.3+'
# Error:invalid literal for int() with base 10: '34.4+'
# Error:invalid literal for int() with base 10: '48.3+'
# Error:invalid literal for int() with base 10: '2.5'
# Error:invalid literal for int() with base 10: '31.5'
# Error:invalid literal for int() with base 10: '49.3+'
# Error:invalid literal for int() with base 10: '11.4+'
# Error:invalid literal for int() with base 10: '26.1'
# Error:invalid literal for int() with base 10: '41.2+'
# Error:invalid literal for int() with base 10: '58.8+'
# Error:invalid literal for int() with base 10: '76.7+'
# Error:invalid literal for int() with base 10: '59.9+'
# Error:invalid literal for int() with base 10: '20.5+'
# Error:invalid literal for int() with base 10: '3.1+'
# Error:invalid literal for int() with base 10: '33.5'
# Error:invalid literal for int() with base 10: '16.1+'
# Error:invalid literal for int() with base 10: '4.2'
# Error:invalid literal for int() with base 10: '67.5'
# Error:invalid literal for int() with base 10: '9.3+'
# Error:invalid literal for int() with base 10: '15.8+'
# Error:invalid literal for int() with base 10: '42.3'
# Error:invalid literal for int() with base 10: '22.3+'
# Error:invalid literal for int() with base 10: '95.6+'
# Error:invalid literal for int() with base 10: '36.7+'
# Error:invalid literal for int() with base 10: '11.7+'
# Error:invalid literal for int() with base 10: '1.2'
# Error:invalid literal for int() with base 10: '1.4+'
# Error:invalid literal for int() with base 10: '38.7'
# Error:invalid literal for int() with base 10: '75+'
# Error:invalid literal for int() with base 10: '106.3+'
# Error:invalid literal for int() with base 10: '87.3+'
# Error:invalid literal for int() with base 10: '18.1+'
# Error:invalid literal for int() with base 10: '4.5+'
# Error:invalid literal for int() with base 10: '45.7+'
# Error:invalid literal for int() with base 10: '94.8+'
# Error:invalid literal for int() with base 10: '28.2+'
# Error:invalid literal for int() with base 10: '11.8+'
# Error:invalid literal for int() with base 10: '42.3+'
# Error:invalid literal for int() with base 10: '35.2+'
# Error:invalid literal for int() with base 10: '31.9+'
# Error:invalid literal for int() with base 10: '27.4+'
# Error:invalid literal for int() with base 10: '4.6+'
# Error:invalid literal for int() with base 10: '4.7+'
# Error:invalid literal for int() with base 10: '1.8+'
# Error:invalid literal for int() with base 10: '36.6+'
# Error:invalid literal for int() with base 10: '25.6+'
# Error:invalid literal for int() with base 10: '34.5+'
# Error:invalid literal for int() with base 10: '9.4+'
# Error:invalid literal for int() with base 10: '1.8+'
# Error:invalid literal for int() with base 10: '32.3+'
# Error:invalid literal for int() with base 10: '30+'
# Error:invalid literal for int() with base 10: '109.8+'
# Error:invalid literal for int() with base 10: '20.2+'
# Error:invalid literal for int() with base 10: '5.1+'
# Error:invalid literal for int() with base 10: '111+'
# Error:invalid literal for int() with base 10: '16.2+'
# Error:invalid literal for int() with base 10: '7.8+'
# Error:invalid literal for int() with base 10: '16.2+'
# Error:invalid literal for int() with base 10: '68.8+'
# Error:invalid literal for int() with base 10: '33.2+'
# Error:invalid literal for int() with base 10: '18.7+'
# Error:invalid literal for int() with base 10: '55.6+'
# Error:invalid literal for int() with base 10: '70.5+'
# Error:invalid literal for int() with base 10: '66.4+'
# Error:invalid literal for int() with base 10: '81.7+'
# Error:invalid literal for int() with base 10: '119.9'
# Error:invalid literal for int() with base 10: '40+'
# Error:invalid literal for int() with base 10: '35.7+'
# Error:invalid literal for int() with base 10: '54+'
# Error:invalid literal for int() with base 10: '19.5+'
# Error:invalid literal for int() with base 10: '133.9'
# Error:invalid literal for int() with base 10: '82.7+'
# Error:invalid literal for int() with base 10: '43.2+'
# Error:invalid literal for int() with base 10: '37.2+'
# Error:invalid literal for int() with base 10: '93+'
# Error:invalid literal for int() with base 10: '32+'
# Error:invalid literal for int() with base 10: '38.6+'
# Error:invalid literal for int() with base 10: '84.1+'
# Error:invalid literal for int() with base 10: '46.8'
# Error:invalid literal for int() with base 10: '35.1+'
# Error:invalid literal for int() with base 10: '9.5+'
# Error:invalid literal for int() with base 10: '57.3+'
# Error:invalid literal for int() with base 10: '61.5+'
# Error:invalid literal for int() with base 10: '40.7+'
# Error:invalid literal for int() with base 10: '49.5+'
# Error:invalid literal for int() with base 10: '45.3+'
# Error:invalid literal for int() with base 10: '57.8'
# Error:invalid literal for int() with base 10: '30+'
# Error:invalid literal for int() with base 10: '41.5+'
# Error:invalid literal for int() with base 10: '83.2+'
# Error:invalid literal for int() with base 10: '127.8+'
# Error:invalid literal for int() with base 10: '37.8+'
# Error:invalid literal for int() with base 10: '33.3+'
# Error:invalid literal for int() with base 10: '7.6+'
# Error:invalid literal for int() with base 10: '2.1+'
# Error:invalid literal for int() with base 10: '95.6+'
# Error:invalid literal for int() with base 10: '24.2+'
# Error:invalid literal for int() with base 10: '38.7+'
# Error:invalid literal for int() with base 10: '93.9+'
# Error:invalid literal for int() with base 10: '54.7+'
# Error:invalid literal for int() with base 10: '40.8+'
# Error:invalid literal for int() with base 10: '13.4+'
# Error:invalid literal for int() with base 10: '52.5+'
# Error:invalid literal for int() with base 10: '39.5+'
# Error:invalid literal for int() with base 10: '33.1+'
# Error:invalid literal for int() with base 10: '48.5+'
# Error:invalid literal for int() with base 10: '65.1+'
# Error:invalid literal for int() with base 10: '27.3+'
# Error:invalid literal for int() with base 10: '9.4+'
# Error:invalid literal for int() with base 10: '37.5+'
# Error:invalid literal for int() with base 10: '26.6+'
# Error:invalid literal for int() with base 10: '55.6+'
# Error:invalid literal for int() with base 10: '40.3+'
# Error:invalid literal for int() with base 10: '109.4+'
# Error:invalid literal for int() with base 10: '6.1+'
# Error:invalid literal for int() with base 10: '14.1+'
# Error:invalid literal for int() with base 10: '5.1+'
# Error:invalid literal for int() with base 10: '6.8+'
# Error:invalid literal for int() with base 10: '21+'
# Error:invalid literal for int() with base 10: '88+'
# Error:invalid literal for int() with base 10: '107.5+'
# Error:invalid literal for int() with base 10: '86.9+'
# Error:invalid literal for int() with base 10: '14.4+'
# Error:invalid literal for int() with base 10: '5.6+'
# Error:invalid literal for int() with base 10: '82.8+'
# Error:invalid literal for int() with base 10: '2.8+'
# Error:invalid literal for int() with base 10: '52.1+'
# Error:invalid literal for int() with base 10: '47.8+'
# Error:invalid literal for int() with base 10: '14.5'
# Error:invalid literal for int() with base 10: '81.4'
# Error:invalid literal for int() with base 10: '41.8+'
# Error:invalid literal for int() with base 10: '3.8+'
# Error:invalid literal for int() with base 10: '42.7+'
# Error:invalid literal for int() with base 10: '42.8+'
# Error:invalid literal for int() with base 10: '78.2+'
# Error:invalid literal for int() with base 10: '82.6+'
# Error:invalid literal for int() with base 10: '54.7+'
# Error:invalid literal for int() with base 10: '22.8+'
# Error:invalid literal for int() with base 10: '9+'
# Error:invalid literal for int() with base 10: '34.9+'
# Error:invalid literal for int() with base 10: '19.4'
# Error:invalid literal for int() with base 10: '108.7+'
# Error:invalid literal for int() with base 10: '61.4+'
# Error:invalid literal for int() with base 10: '32.6+'
# Error:invalid literal for int() with base 10: '20.2+'
# Error:invalid literal for int() with base 10: '36.1+'
# Error:invalid literal for int() with base 10: '60.5+'
# Error:invalid literal for int() with base 10: '49.5+'
# Error:invalid literal for int() with base 10: '20.1+'
# Error:invalid literal for int() with base 10: '45.6+'
# Error:invalid literal for int() with base 10: '20.8+'
# Error:invalid literal for int() with base 10: '2.7+'
# Error:invalid literal for int() with base 10: '105+'
# Error:invalid literal for int() with base 10: '57.8+'
# Error:invalid literal for int() with base 10: '63.3+'
# Error:invalid literal for int() with base 10: '32.3+'
# Error:invalid literal for int() with base 10: '39.1+'
# Error:invalid literal for int() with base 10: '52.8+'
# Error:invalid literal for int() with base 10: '6+'
# Error:invalid literal for int() with base 10: '11.4+'
# Error:invalid literal for int() with base 10: '91.8+'
# Error:invalid literal for int() with base 10: '23.2+'
# Error:invalid literal for int() with base 10: '18.5+'
# Error:invalid literal for int() with base 10: '76.9+'
# Error:invalid literal for int() with base 10: '2.8+'
# Error:invalid literal for int() with base 10: '54.1+'
# Error:invalid literal for int() with base 10: '17.2+'
# Error:invalid literal for int() with base 10: '113.3+'
# Error:invalid literal for int() with base 10: '9.6+'
# Error:invalid literal for int() with base 10: '36.2+'
# Error:invalid literal for int() with base 10: '61.8+'
# Error:invalid literal for int() with base 10: '1.9+'
# Error:invalid literal for int() with base 10: '48.9+'
# Error:invalid literal for int() with base 10: '24.2'
# Error:invalid literal for int() with base 10: '68.6+'
# Error:invalid literal for int() with base 10: '90.2+'
# Error:invalid literal for int() with base 10: '7.2'
# Error:invalid literal for int() with base 10: '52+'
# Error:invalid literal for int() with base 10: '10.1+'
# Error:invalid literal for int() with base 10: '60.1+'
# Error:invalid literal for int() with base 10: '59.9+'
# Error:invalid literal for int() with base 10: '56.8'
# Error:invalid literal for int() with base 10: '65.8+'
# Error:invalid literal for int() with base 10: '31.6+'
# Error:invalid literal for int() with base 10: '26.1+'
# Error:invalid literal for int() with base 10: '15+'
# Error:invalid literal for int() with base 10: '40.9+'
# Error:invalid literal for int() with base 10: '12.3+'
# Error:invalid literal for int() with base 10: '29+'
# Error:invalid literal for int() with base 10: '91.5+'
# Error:invalid literal for int() with base 10: '43.3+'
# Error:invalid literal for int() with base 10: '31.9+'
# Error:invalid literal for int() with base 10: '28.6+'
# Error:invalid literal for int() with base 10: '52.6+'
# Error:invalid literal for int() with base 10: '1.4+'
# Error:invalid literal for int() with base 10: '88+'
# Error:invalid literal for int() with base 10: '129+'
# Error:invalid literal for int() with base 10: '70.1'
# Error:invalid literal for int() with base 10: '18.5+'
# Error:invalid literal for int() with base 10: '59.3'
# Error:invalid literal for int() with base 10: '40.6+'
# Error:invalid literal for int() with base 10: '22.5+'
# Error:invalid literal for int() with base 10: '15.2+'
# Error:invalid literal for int() with base 10: '38.2+'
# Error:invalid literal for int() with base 10: '41.4+'
# Error:invalid literal for int() with base 10: '105.9+'
# Error:invalid literal for int() with base 10: '28.3+'
# Error:invalid literal for int() with base 10: '70.6+'
# Error:invalid literal for int() with base 10: '5.5'
# Error:invalid literal for int() with base 10: '44+'
# Error:invalid literal for int() with base 10: '12.9+'
# Error:invalid literal for int() with base 10: '52.6+'
# Error:invalid literal for int() with base 10: '104.9+'
# Error:invalid literal for int() with base 10: '93.4+'
# Error:invalid literal for int() with base 10: '24.2+'
# Error:invalid literal for int() with base 10: '44.3+'
# Error:invalid literal for int() with base 10: '41.3+'
# Error:invalid literal for int() with base 10: '19.3+'
# Error:invalid literal for int() with base 10: '15.6+'
# Error:invalid literal for int() with base 10: '79.9+'
# Error:invalid literal for int() with base 10: '83.8+'
# Error:invalid literal for int() with base 10: '54.6+'
# Error:invalid literal for int() with base 10: '16.4+'
# Error:invalid literal for int() with base 10: '93.7+'
# Error:invalid literal for int() with base 10: '25.8+'
# Error:invalid literal for int() with base 10: '5.3+'
# Error:invalid literal for int() with base 10: '38.2+'
# Error:invalid literal for int() with base 10: '14.6+'
# Error:invalid literal for int() with base 10: '57.8+'
# Error:invalid literal for int() with base 10: '157.5+'
# Error:invalid literal for int() with base 10: '50.1+'
# Error:invalid literal for int() with base 10: '16.7+'
# Error:invalid literal for int() with base 10: '19.4+'
# Error:invalid literal for int() with base 10: '24.5+'
# Error:invalid literal for int() with base 10: '5.2+'
# Error:invalid literal for int() with base 10: '57.5+'
# Error:invalid literal for int() with base 10: '45.4+'
# Error:invalid literal for int() with base 10: '37.9+'
# Error:invalid literal for int() with base 10: '53.8+'
# Error:invalid literal for int() with base 10: '24.9+'
# Error:invalid literal for int() with base 10: '101.1+'
# Error:invalid literal for int() with base 10: '1.3+'
# Error:invalid literal for int() with base 10: '53.1+'
# Error:invalid literal for int() with base 10: '97.9+'
# Error:invalid literal for int() with base 10: '4.3+'
# Error:invalid literal for int() with base 10: '23.4'
# Error:invalid literal for int() with base 10: '79.5+'
# Error:invalid literal for int() with base 10: '97.7+'
# Error:invalid literal for int() with base 10: '7.4+'
# Error:invalid literal for int() with base 10: '83.9+'
# Error:invalid literal for int() with base 10: '21.9+'
# Error:invalid literal for int() with base 10: '24.9+'
# Error:invalid literal for int() with base 10: '4.5+'
# Error:invalid literal for int() with base 10: '3.2+'
# Data Saved in cazooCarsDataset.csv!
